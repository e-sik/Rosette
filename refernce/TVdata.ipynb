# %%
pip install --upgrade --no-cache-dir git+https://github.com/rongardF/tvdatafeed.git
# Out:
# Collecting git+https://github.com/rongardF/tvdatafeed.git
#   Cloning https://github.com/rongardF/tvdatafeed.git to c:\users\admin\appdata\local\temp\pip-req-build-fprpk0ou
#   Resolved https://github.com/rongardF/tvdatafeed.git to commit e6f6aaa7de439ac6e454d9b26d2760ded8dc4923
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting setuptools (from tvdatafeed==2.1.0)
#   Downloading setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas in c:\users\admin\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from tvdatafeed==2.1.0) (2.3.3)
# Collecting websocket-client (from tvdatafeed==2.1.0)
#   Downloading websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting requests (from tvdatafeed==2.1.0)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas->tvdatafeed==2.1.0) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\roaming\python\python314\site-packages (from pandas->tvdatafeed==2.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas->tvdatafeed==2.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas->tvdatafeed==2.1.0) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas->tvdatafeed==2.1.0) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests->tvdatafeed==2.1.0)
#   Downloading charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests->tvdatafeed==2.1.0)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->tvdatafeed==2.1.0)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests->tvdatafeed==2.1.0)
#   Downloading certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl (107 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
# Downloading setuptools-80.9.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------- ----- 1.0/1.2 MB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 4.4 MB/s  0:00:00
# Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Building wheels for collected packages: tvdatafeed
#   Building wheel for tvdatafeed (pyproject.toml): started
#   Building wheel for tvdatafeed (pyproject.toml): finished with status 'done'
#   Created wheel for tvdatafeed: filename=tvdatafeed-2.1.0-py3-none-any.whl size=17634 sha256=180172fff073457d2e4f1d1ad835d0c0e7cd933fa3e31e757401169992e6278d
#   Stored in directory: C:\Users\admin\AppData\Local\Temp\pip-ephem-wheel-cache-2fxb8ft_\wheels\76\3f\60\b0c92710f6782786d186b04e7c5abe17ca26c352288d8a2281
# Successfully built tvdatafeed
# Installing collected packages: websocket-client, urllib3, setuptools, idna, charset_normalizer, certifi, requests, tvdatafeed
#
#    ---------------------------------------- 0/8 [websocket-client]
#    ---------------------------------------- 0/8 [websocket-client]
#    ---------------------------------------- 0/8 [websocket-client]
#    ---------------------------------------- 0/8 [websocket-client]
#    ---------------------------------------- 0/8 [websocket-client]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    ---------- ----------------------------- 2/8 [setuptools]
#    --------------- ------------------------ 3/8 [idna]
#    --------------- ------------------------ 3/8 [idna]
#    -------------------- ------------------- 4/8 [charset_normalizer]
#    -------------------- ------------------- 4/8 [charset_normalizer]
#    ------------------------- -------------- 5/8 [certifi]
#    ------------------------------ --------- 6/8 [requests]
#    ------------------------------ --------- 6/8 [requests]
#    ------------------------------ --------- 6/8 [requests]
#    ---------------------------------------- 8/8 [tvdatafeed]
#
# Successfully installed certifi-2026.1.4 charset_normalizer-3.4.4 idna-3.11 requests-2.32.5 setuptools-80.9.0 tvdatafeed-2.1.0 urllib3-2.6.3 websocket-client-1.9.0
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/rongardF/tvdatafeed.git 'C:\Users\admin\AppData\Local\Temp\pip-req-build-fprpk0ou'
#   WARNING: The script wsdump.exe is installed in 'c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\admin\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
from tvDatafeed import TvDatafeed, Interval

# login with TradingView credentials
tv = TvDatafeed()
# Out:
# you are using nologin method, data you access may be limited

# %%
# Try fetching SBIN directly 
df = tv.get_hist('SBIN', 'NSE', Interval.in_daily, 10) 
print(df.head())
# Out:
#                        symbol     open     high      low    close     volume
# datetime
# 2026-01-06 09:15:00  NSE:SBIN  1007.95  1024.00  1004.95  1018.90  9575742.0
# 2026-01-07 09:15:00  NSE:SBIN  1022.70  1022.70  1004.00  1007.15  7896720.0
# 2026-01-08 09:15:00  NSE:SBIN  1006.60  1011.60   995.85   998.00  6854268.0
# 2026-01-09 09:15:00  NSE:SBIN   996.00  1008.00   994.00  1000.50  7809460.0
# 2026-01-12 09:15:00  NSE:SBIN  1008.00  1017.25   996.00  1015.15  7617922.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2026-01-06 09:15:00 to 2026-01-20 09:15:00
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   symbol  10 non-null     object
#  1   open    10 non-null     float64
#  2   high    10 non-null     float64
#  3   low     10 non-null     float64
#  4   close   10 non-null     float64
#  5   volume  10 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 560.0+ bytes
